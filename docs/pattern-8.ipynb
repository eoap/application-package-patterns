# %%
# %load_ext autoreload
# %autoreload 2

import json

pattern = "pattern-8"

entrypoint = pattern
app_cwl_file = f"../cwl-workflow/{pattern}.cwl"

with open(f"../cwl-workflow/{pattern}-inputs.json", "r") as f:
    app_inputs = json.load(f)


try:
    from docs.helpers import plot_cwl, wrap_cwl
except (ImportError, ModuleNotFoundError) as e:

    import os
    import sys

    module_path = os.path.abspath(os.path.join("."))  # or the path to your source code
    sys.path.insert(0, module_path)

from helpers import WorkflowViewer, WorkflowWrapper, additional_inputs
from cwl_loader import dump_cwl
from IPython.display import Markdown, display
import json

# %%
wf = WorkflowViewer.from_file(app_cwl_file, entrypoint)
# Out:
# 2025-12-03 10:37:24.723 | DEBUG    | cwl_loader:load_cwl_from_location:228 - Loading CWL document from ../cwl-workflow/pattern-8.cwl...
# 2025-12-03 10:37:24.724 | DEBUG    | cwl_loader:_load_cwl_from_stream:231 - Reading stream from ../cwl-workflow/pattern-8.cwl...
# 2025-12-03 10:37:24.734 | DEBUG    | cwl_loader:load_cwl_from_stream:203 - CWL data of type <class 'ruamel.yaml.comments.CommentedMap'> successfully loaded from stream
# 2025-12-03 10:37:24.735 | DEBUG    | cwl_loader:load_cwl_from_yaml:130 - Updating the model from version 'v1.0' to version 'v1.2'...
# 2025-12-03 10:37:24.735 | DEBUG    | cwl_loader:load_cwl_from_yaml:141 - Raw CWL document successfully updated to v1.2!
# 2025-12-03 10:37:24.736 | DEBUG    | cwl_loader:load_cwl_from_yaml:145 - Parsing the raw CWL document to the CWL Utils DOM...
# 2025-12-03 10:37:25.031 | DEBUG    | cwl_loader:load_cwl_from_yaml:158 - Raw CWL document successfully parsed to the CWL Utils DOM!
# 2025-12-03 10:37:25.032 | DEBUG    | cwl_loader:load_cwl_from_yaml:160 - Dereferencing the steps[].run...
# 2025-12-03 10:37:25.032 | DEBUG    | cwl_loader:_on_process:78 - Checking if ../cwl-workflow/pattern-8.cwl#clt must be externally imported...
# 2025-12-03 10:37:25.032 | DEBUG    | cwl_loader:_on_process:82 - run_url: ../cwl-workflow/pattern-8.cwl - uri: ../cwl-workflow/pattern-8.cwl
# 2025-12-03 10:37:25.033 | DEBUG    | cwl_loader:load_cwl_from_yaml:167 - steps[].run successfully dereferenced! Dereferencing the FQNs...
# 2025-12-03 10:37:25.033 | DEBUG    | cwl_loader:load_cwl_from_yaml:171 - CWL document successfully dereferenced! Now verifying steps[].run integrity...
# 2025-12-03 10:37:25.033 | DEBUG    | cwl_loader:load_cwl_from_yaml:175 - All steps[].run link are resolvable!
# 2025-12-03 10:37:25.033 | DEBUG    | cwl_loader:load_cwl_from_yaml:178 - Sorting Process instances by dependencies....
# 2025-12-03 10:37:25.033 | DEBUG    | cwl_loader:load_cwl_from_yaml:180 - Sorting process is over.
# 2025-12-03 10:37:25.033 | DEBUG    | cwl_loader:_load_cwl_from_stream:240 - Stream from ../cwl-workflow/pattern-8.cwl successfully load!

# %% [markdown]
# ## Application Package Pattern 8
#
# The CWL includes:
# - one input parameter of type `Directory`
# - one output parameter of type `Directory?`
#
# This scenario takes as input an acquisition, applies an algorithm and may or may not generate and output
#
# Implementation: detects water bodies using the Normalized Difference Water Index (NDWI) and Otsu thresholding.

# %%
wf.plot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=366x559>

# %% [markdown]
# ### Inputs

# %%
wf.display_inputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `aoi` | `string` | area of interest | area of interest as a bounding box |
# | `epsg` | `string` | EPSG code | EPSG code |
# | `bands` | `string[]` | bands used for the NDWI | bands used for the NDWI |
# | `item` | `Directory` | Landsat-8/9 acquisition reference | Landsat-8/9 acquisition reference |
# | `produce_output` | `boolean` | Flag to produce the output | Flag to produce the output |

# %% [markdown]
# ### Steps

# %%
wf.display_steps()
# Out:
# | Id | Runs | Label | Doc |
# | --- | --- | --- | --- |
# | `step` | `#clt` | None | None |

# %% [markdown]
# ### Outputs

# %%
wf.display_outputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `water_bodies` | `[ null, Directory ]` | Water bodies detected | Water bodies detected based on the NDWI and otsu threshold |

# %% [markdown]
# ## Data flow management

# %%
w = WorkflowWrapper(workflow=wf.workflow, entrypoint=entrypoint)
wrapped = w.wrap()

app_cwl_file = f".{entrypoint}.cwl"

with open(app_cwl_file, "w") as f:
    dump_cwl(process=wrapped, stream=f)
# Out:
# 2025-12-03 10:37:26.919 | DEBUG    | cwl_loader:load_cwl_from_location:228 - Loading CWL document from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in.cwl...
# 2025-12-03 10:37:26.970 | DEBUG    | cwl_loader:_load_cwl_from_stream:231 - Reading stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in.cwl...
# 2025-12-03 10:37:26.973 | DEBUG    | cwl_loader:load_cwl_from_stream:203 - CWL data of type <class 'ruamel.yaml.comments.CommentedMap'> successfully loaded from stream
# 2025-12-03 10:37:26.973 | DEBUG    | cwl_loader:load_cwl_from_yaml:130 - Updating the model from version 'v1.0' to version 'v1.2'...
# 2025-12-03 10:37:26.974 | DEBUG    | cwl_loader:load_cwl_from_yaml:141 - Raw CWL document successfully updated to v1.2!
# 2025-12-03 10:37:26.974 | DEBUG    | cwl_loader:load_cwl_from_yaml:145 - Parsing the raw CWL document to the CWL Utils DOM...
# 2025-12-03 10:37:27.390 | DEBUG    | cwl_loader:load_cwl_from_yaml:158 - Raw CWL document successfully parsed to the CWL Utils DOM!
# 2025-12-03 10:37:27.391 | DEBUG    | cwl_loader:load_cwl_from_yaml:160 - Dereferencing the steps[].run...
# 2025-12-03 10:37:27.392 | DEBUG    | cwl_loader:load_cwl_from_yaml:167 - steps[].run successfully dereferenced! Dereferencing the FQNs...
# 2025-12-03 10:37:27.392 | DEBUG    | cwl_loader:load_cwl_from_yaml:171 - CWL document successfully dereferenced! Now verifying steps[].run integrity...
# 2025-12-03 10:37:27.392 | DEBUG    | cwl_loader:load_cwl_from_yaml:175 - All steps[].run link are resolvable!
# 2025-12-03 10:37:27.392 | DEBUG    | cwl_loader:load_cwl_from_yaml:178 - Sorting Process instances by dependencies....
# 2025-12-03 10:37:27.392 | DEBUG    | cwl_loader:load_cwl_from_yaml:180 - Sorting process is over.
# 2025-12-03 10:37:27.393 | DEBUG    | cwl_loader:_load_cwl_from_stream:240 - Stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in.cwl successfully load!
# 2025-12-03 10:37:27.393 | DEBUG    | cwl_loader:load_cwl_from_location:228 - Loading CWL document from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in-file.cwl...
# 2025-12-03 10:37:27.442 | DEBUG    | cwl_loader:_load_cwl_from_stream:231 - Reading stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in-file.cwl...
# 2025-12-03 10:37:27.446 | DEBUG    | cwl_loader:load_cwl_from_stream:203 - CWL data of type <class 'ruamel.yaml.comments.CommentedMap'> successfully loaded from stream
# 2025-12-03 10:37:27.446 | DEBUG    | cwl_loader:load_cwl_from_yaml:130 - Updating the model from version 'v1.0' to version 'v1.2'...
# 2025-12-03 10:37:27.447 | DEBUG    | cwl_loader:load_cwl_from_yaml:141 - Raw CWL document successfully updated to v1.2!
# 2025-12-03 10:37:27.447 | DEBUG    | cwl_loader:load_cwl_from_yaml:145 - Parsing the raw CWL document to the CWL Utils DOM...
# 2025-12-03 10:37:27.860 | DEBUG    | cwl_loader:load_cwl_from_yaml:158 - Raw CWL document successfully parsed to the CWL Utils DOM!
# 2025-12-03 10:37:27.860 | DEBUG    | cwl_loader:load_cwl_from_yaml:160 - Dereferencing the steps[].run...
# 2025-12-03 10:37:27.861 | DEBUG    | cwl_loader:load_cwl_from_yaml:167 - steps[].run successfully dereferenced! Dereferencing the FQNs...
# 2025-12-03 10:37:27.861 | DEBUG    | cwl_loader:load_cwl_from_yaml:171 - CWL document successfully dereferenced! Now verifying steps[].run integrity...
# 2025-12-03 10:37:27.861 | DEBUG    | cwl_loader:load_cwl_from_yaml:175 - All steps[].run link are resolvable!
# 2025-12-03 10:37:27.861 | DEBUG    | cwl_loader:load_cwl_from_yaml:178 - Sorting Process instances by dependencies....
# 2025-12-03 10:37:27.862 | DEBUG    | cwl_loader:load_cwl_from_yaml:180 - Sorting process is over.
# 2025-12-03 10:37:27.862 | DEBUG    | cwl_loader:_load_cwl_from_stream:240 - Stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in-file.cwl successfully load!
# 2025-12-03 10:37:27.862 | DEBUG    | cwl_loader:load_cwl_from_location:228 - Loading CWL document from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-out.cwl...
# 2025-12-03 10:37:27.909 | DEBUG    | cwl_loader:_load_cwl_from_stream:231 - Reading stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-out.cwl...
# 2025-12-03 10:37:27.916 | DEBUG    | cwl_loader:load_cwl_from_stream:203 - CWL data of type <class 'ruamel.yaml.comments.CommentedMap'> successfully loaded from stream
# 2025-12-03 10:37:27.916 | DEBUG    | cwl_loader:load_cwl_from_yaml:130 - Updating the model from version 'v1.0' to version 'v1.2'...
# 2025-12-03 10:37:27.916 | DEBUG    | cwl_loader:load_cwl_from_yaml:141 - Raw CWL document successfully updated to v1.2!
# 2025-12-03 10:37:27.917 | DEBUG    | cwl_loader:load_cwl_from_yaml:145 - Parsing the raw CWL document to the CWL Utils DOM...
# 2025-12-03 10:37:28.377 | DEBUG    | cwl_loader:load_cwl_from_yaml:158 - Raw CWL document successfully parsed to the CWL Utils DOM!
# 2025-12-03 10:37:28.378 | DEBUG    | cwl_loader:load_cwl_from_yaml:160 - Dereferencing the steps[].run...
# 2025-12-03 10:37:28.379 | DEBUG    | cwl_loader:load_cwl_from_yaml:167 - steps[].run successfully dereferenced! Dereferencing the FQNs...
# 2025-12-03 10:37:28.379 | DEBUG    | cwl_loader:load_cwl_from_yaml:171 - CWL document successfully dereferenced! Now verifying steps[].run integrity...
# 2025-12-03 10:37:28.379 | DEBUG    | cwl_loader:load_cwl_from_yaml:175 - All steps[].run link are resolvable!
# 2025-12-03 10:37:28.379 | DEBUG    | cwl_loader:load_cwl_from_yaml:178 - Sorting Process instances by dependencies....
# 2025-12-03 10:37:28.379 | DEBUG    | cwl_loader:load_cwl_from_yaml:180 - Sorting process is over.
# 2025-12-03 10:37:28.380 | DEBUG    | cwl_loader:_load_cwl_from_stream:240 - Stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-out.cwl successfully load!
# 2025-12-03 10:37:28.380 | INFO     | eoap_cwlwrap.types:_validate_stage_in:281 - Validating stage-in 'my-asthonishing-stage-in-directory'...
# 2025-12-03 10:37:28.380 | INFO     | eoap_cwlwrap.types:_validate_stage_in:303 - stage-in 'my-asthonishing-stage-in-directory' is valid
# 2025-12-03 10:37:28.380 | INFO     | eoap_cwlwrap.types:_validate_stage_in:281 - Validating stage-in 'my-asthonishing-stage-in-file'...
# 2025-12-03 10:37:28.380 | INFO     | eoap_cwlwrap.types:_validate_stage_in:303 - stage-in 'my-asthonishing-stage-in-file' is valid
# 2025-12-03 10:37:28.381 | INFO     | eoap_cwlwrap.types:validate_stage_out:339 - Validating stage-out 'my-super-stage-out'...
# 2025-12-03 10:37:28.381 | INFO     | eoap_cwlwrap.types:validate_stage_out:361 - stage-out 'my-super-stage-out' is valid
# 2025-12-03 10:37:28.381 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:101 - Building the CWL Orchestrator Workflow...
# 2025-12-03 10:37:28.381 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:130 - Analyzing pattern-8 inputs...
# 2025-12-03 10:37:28.382 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:146 - * pattern-8/aoi: string
# 2025-12-03 10:37:28.382 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:146 - * pattern-8/epsg: string
# 2025-12-03 10:37:28.382 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:146 - * pattern-8/bands: string[]
# 2025-12-03 10:37:28.382 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:146 - * pattern-8/item: Directory
# 2025-12-03 10:37:28.382 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:159 -   Directory type detected, creating a related 'directory_stage_in_0'...
# 2025-12-03 10:37:28.383 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:161 -   Converting Directory to URL-compatible type...
# 2025-12-03 10:37:28.383 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:165 -   Directory converted to https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI
# 2025-12-03 10:37:28.383 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:206 -   Connecting 'app/item' to 'directory_stage_in_0' output...
# 2025-12-03 10:37:28.384 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:146 - * pattern-8/produce_output: boolean
# 2025-12-03 10:37:28.384 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:257 - Analyzing pattern-8 outputs...
# 2025-12-03 10:37:28.384 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:263 - * pattern-8/water_bodies: [ null, Directory ]
# 2025-12-03 10:37:28.384 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:268 -   Directory type detected, creating a related 'stage_out_0'...
# 2025-12-03 10:37:28.384 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:270 -   Converting [ null, Directory ] to URL-compatible type...
# 2025-12-03 10:37:28.385 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:274 -   [ null, Directory ] converted to [ null, https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI ]
# 2025-12-03 10:37:28.385 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:306 -   Nullable detected, 'when' required for stac_catalog:app/water_bodies
# 2025-12-03 10:37:28.385 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:315 -   Connecting 'app/water_bodies' to 'stage_out_0' output...
# 2025-12-03 10:37:28.386 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:390 - Orchestrator Workflow built in 0.0047 seconds

# %%
wf = WorkflowViewer(cwl_file=app_cwl_file, workflow=wrapped, entrypoint="main")

wf.display_class_diagram()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=1153x1625>

# %% [markdown]
# ### Workflow sequence diagram

# %%
wf.display_sequence_diagram()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=1903x1488>

# %% [markdown]
# ### Inputs

# %%
wf.display_inputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `aoi` | `string` | area of interest - pattern-8/aoi | area of interest as a bounding box - This parameter is derived from pattern-8/aoi |
# | `epsg` | `string` | EPSG code - pattern-8/epsg | EPSG code - This parameter is derived from pattern-8/epsg |
# | `bands` | `string[]` | bands used for the NDWI - pattern-8/bands | bands used for the NDWI - This parameter is derived from pattern-8/bands |
# | `another_input` | `string` | Another Input - my-asthonishing-stage-in-directory/another_input | An additional input for demonstration purposes - This parameter is derived from my-asthonishing-stage-in-directory/another_input |
# | `item` | `https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI` | Landsat-8/9 acquisition reference - pattern-8/item | Landsat-8/9 acquisition reference - This parameter is derived from pattern-8/item |
# | `produce_output` | `boolean` | Flag to produce the output - pattern-8/produce_output | Flag to produce the output - This parameter is derived from pattern-8/produce_output |
# | `s3_bucket` | `string` | my-super-stage-out/s3_bucket | This parameter is derived from: my-super-stage-out/s3_bucket |
# | `sub_path` | `string` | my-super-stage-out/sub_path | This parameter is derived from: my-super-stage-out/sub_path |
# | `aws_access_key_id` | `string` | my-super-stage-out/aws_access_key_id | This parameter is derived from: my-super-stage-out/aws_access_key_id |
# | `aws_secret_access_key` | `string` | my-super-stage-out/aws_secret_access_key | This parameter is derived from: my-super-stage-out/aws_secret_access_key |
# | `region_name` | `string` | my-super-stage-out/region_name | This parameter is derived from: my-super-stage-out/region_name |
# | `endpoint_url` | `string` | my-super-stage-out/endpoint_url | This parameter is derived from: my-super-stage-out/endpoint_url |

# %% [markdown]
# ### Steps

# %%
wf.display_steps()
# Out:
# | Id | Runs | Label | Doc |
# | --- | --- | --- | --- |
# | `directory_stage_in_0` | `#my-asthonishing-stage-in-directory` | None | None |
# | `app` | `#pattern-8` | None | None |
# | `stage_out_0` | `#my-super-stage-out` | None | None |

# %% [markdown]
# ### Outputs

# %%
wf.display_outputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `water_bodies` | `[ null, https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI ]` | Water bodies detected | Water bodies detected based on the NDWI and otsu threshold |

# %% [markdown]
# ## Execution

# %%
from cwltool.main import main
from io import StringIO
import argparse
import yaml

# %%
with open(".params.yaml", "w") as f:
    yaml.dump({**app_inputs, **additional_inputs}, f)

md = f"""

### Inputs

```json
{json.dumps({**app_inputs, **additional_inputs}, indent=2)}
```
"""

display(Markdown(md))
# Out:
# ### Inputs
#
# ```json
# {
#   "aoi": "-118.985,38.432,-118.183,38.938",
#   "epsg": "EPSG:4326",
#   "bands": [
#     "green",
#     "nir08"
#   ],
#   "item": {
#     "class": "https://raw.githubusercontent.com/eoap/schemas/main/url.yaml#URL",
#     "value": "https://planetarycomputer.microsoft.com/api/stac/v1/collections/landsat-c2-l2/items/LC08_L2SP_042033_20231007_02_T1"
#   },
#   "produce_output": true
# }
# ```

# %%
parsed_args = argparse.Namespace(
    podman=False,
    debug=False,
    validate=False,
    outdir="./runs",
    workflow=f"{app_cwl_file}#main",
    job_order=[".params.yaml"],
)

stream_out = StringIO()
stream_err = StringIO()

res = main(
    args=parsed_args,
    stdout=stream_out,
    stderr=stream_err,
)

if res == 0:
    md = f"""

### Outputs

```json
{stream_out.getvalue()}
```
    """
else:
    md = f"""

### Errors

CWL execution terminated with errors:

```
{stream_err.getvalue()}
```
    """

display(Markdown(md))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 13
#      10 stream_out = StringIO()
#      11 stream_err = StringIO()
# ---> 13 res = main(
#      14     args=parsed_args,
#      15     stdout=stream_out,
#      16     stderr=stream_err,
#      17 )
#      19 if res == 0:
#      20     md = f"""
#      21
#      22 ### Outputs
#    (...)     26 ```
#      27     """
#
# File ~/Documents/eoepca/application-package-patterns/.venv/lib/python3.13/site-packages/cwltool/main.py:1313, in main(argsl, args, job_order_object, stdin, stdout, stderr, versionfunc, logger_handler, custom_schema_callback, executor, loadingContext, runtimeContext, input_required)
#    1310 runtimeContext.validate_only = args.validate
#    1311 runtimeContext.validate_stdout = stdout
# -> 1313 (out, status) = real_executor(
#    1314     tool, initialized_job_order_object, runtimeContext, logger=_logger
#    1315 )
#    1316 if runtimeContext.validate_only is True:
#    1317     return 0
#
# File ~/Documents/eoepca/application-package-patterns/.venv/lib/python3.13/site-packages/cwltool/executors.py:53, in JobExecutor.__call__(self, process, job_order_object, runtime_context, logger)
#      46 def __call__(
#      47     self,
#      48     process: Process,
#    (...)     51     logger: logging.Logger = _logger,
#      52 ) -> tuple[Optional[CWLObjectType], str]:
# ---> 53     return self.execute(process, job_order_object, runtime_context, logger)
#
# File ~/Documents/eoepca/application-package-patterns/.venv/lib/python3.13/site-packages/cwltool/executors.py:136, in JobExecutor.execute(self, process, job_order_object, runtime_context, logger)
#     133     for req in job_reqs:
#     134         process.requirements.append(req)
# --> 136 self.run_jobs(process, job_order_object, logger, runtime_context)
#     137 if runtime_context.validate_only is True:
#     138     return (None, "ValidationSuccess")
#
# File ~/Documents/eoepca/application-package-patterns/.venv/lib/python3.13/site-packages/cwltool/executors.py:246, in SingleJobExecutor.run_jobs(self, process, job_order_object, logger, runtime_context)
#     241         print(
#     242             f"{name} is valid CWL. No errors detected in the inputs.",
#     243             file=runtime_context.validate_stdout,
#     244         )
#     245         return
# --> 246     job.run(runtime_context)
#     247 else:
#     248     logger.error("Workflow cannot make any more progress.")
#
# File ~/Documents/eoepca/application-package-patterns/.venv/lib/python3.13/site-packages/cwltool/job.py:855, in ContainerCommandLineJob.run(self, runtimeContext, tmpdir_lock)
#     853 elif runtimeContext.user_space_docker_cmd:
#     854     monitor_function = functools.partial(self.process_monitor)
# --> 855 self._execute(runtime, env, runtimeContext, monitor_function)
#
# File ~/Documents/eoepca/application-package-patterns/.venv/lib/python3.13/site-packages/cwltool/job.py:323, in JobBase._execute(self, runtime, env, runtimeContext, monitor_function)
#     321 if builder is not None:
#     322     job_script_contents = builder.build_job_script(commands)
# --> 323 rcode = _job_popen(
#     324     commands,
#     325     stdin_path=stdin_path,
#     326     stdout_path=stdout_path,
#     327     stderr_path=stderr_path,
#     328     env=env,
#     329     cwd=self.outdir,
#     330     make_job_dir=lambda: runtimeContext.create_outdir(),
#     331     job_script_contents=job_script_contents,
#     332     timelimit=self.timelimit,
#     333     name=self.name,
#     334     monitor_function=monitor_function,
#     335     default_stdout=runtimeContext.default_stdout,
#     336     default_stderr=runtimeContext.default_stderr,
#     337 )
#     339 if rcode in self.successCodes:
#     340     processStatus = "success"
#
# File ~/Documents/eoepca/application-package-patterns/.venv/lib/python3.13/site-packages/cwltool/job.py:998, in _job_popen(commands, stdin_path, stdout_path, stderr_path, env, cwd, make_job_dir, job_script_contents, timelimit, name, monitor_function, default_stdout, default_stderr)
#     996     tm.start()
#     997 if monitor_function:
# --> 998     monitor_function(sproc)
#     999 rcode = sproc.wait()
#    1001 if tm is not None:
#
# File ~/Documents/eoepca/application-package-patterns/.venv/lib/python3.13/site-packages/cwltool/job.py:905, in ContainerCommandLineJob.docker_monitor(self, cidfile, tmpdir_prefix, cleanup_cidfile, docker_exe, process)
#     899         cmds.extend(["--format", "{{.MemPerc}}", cid])
#     900         stats_proc = subprocess.Popen(  # nosec
#     901             cmds,
#     902             stdout=stats_file_handle,
#     903             stderr=subprocess.DEVNULL,
#     904         )
# --> 905         process.wait()
#     906         stats_proc.kill()
#     907 except OSError as exc:
#
# File /usr/lib/python3.13/subprocess.py:1280, in Popen.wait(self, timeout)
#    1278     endtime = _time() + timeout
#    1279 try:
# -> 1280     return self._wait(timeout=timeout)
#    1281 except KeyboardInterrupt:
#    1282     # https://bugs.python.org/issue25942
#    1283     # The first keyboard interrupt waits briefly for the child to
#    1284     # exit under the common assumption that it also received the ^C
#    1285     # generated SIGINT and will exit rapidly.
#    1286     if timeout is not None:
#
# File /usr/lib/python3.13/subprocess.py:2066, in Popen._wait(self, timeout)
#    2064 if self.returncode is not None:
#    2065     break  # Another thread waited.
# -> 2066 (pid, sts) = self._try_wait(0)
#    2067 # Check the pid and loop as waitpid has been known to
#    2068 # return 0 even without WNOHANG in odd situations.
#    2069 # http://bugs.python.org/issue14396.
#    2070 if pid == self.pid:
#
# File /usr/lib/python3.13/subprocess.py:2024, in Popen._try_wait(self, wait_flags)
#    2022 """All callers to this function MUST hold self._waitpid_lock."""
#    2023 try:
# -> 2024     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2025 except ChildProcessError:
#    2026     # This happens if SIGCLD is set to be ignored or waiting
#    2027     # for child processes has otherwise been disabled for our
#    2028     # process.  This child is dead, we can't get the status.
#    2029     pid = self.pid
#
# KeyboardInterrupt:
