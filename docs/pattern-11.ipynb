# %%
# %load_ext autoreload
# %autoreload 2

pattern = "pattern-11"

entrypoint = pattern
app_cwl_file = f"../cwl-workflow/{pattern}.cwl"

try:
    from docs.helpers import plot_cwl, wrap_cwl
except (ImportError, ModuleNotFoundError) as e:

    import os
    import sys

    module_path = os.path.abspath(os.path.join("."))  # or the path to your source code
    sys.path.insert(0, module_path)

from helpers import WorkflowViewer, WorkflowWrapper
from cwl_loader import dump_cwl
from IPython.display import Markdown, display
import json

# %%
wf = WorkflowViewer.from_file(app_cwl_file, entrypoint)
# Out:
# 2025-12-03 11:29:09.878 | DEBUG    | cwl_loader:load_cwl_from_location:228 - Loading CWL document from ../cwl-workflow/pattern-11.cwl...
# 2025-12-03 11:29:09.879 | DEBUG    | cwl_loader:_load_cwl_from_stream:231 - Reading stream from ../cwl-workflow/pattern-11.cwl...
# 2025-12-03 11:29:09.891 | DEBUG    | cwl_loader:load_cwl_from_stream:203 - CWL data of type <class 'ruamel.yaml.comments.CommentedMap'> successfully loaded from stream
# 2025-12-03 11:29:09.891 | DEBUG    | cwl_loader:load_cwl_from_yaml:130 - Updating the model from version 'v1.0' to version 'v1.2'...
# 2025-12-03 11:29:09.891 | DEBUG    | cwl_loader:load_cwl_from_yaml:141 - Raw CWL document successfully updated to v1.2!
# 2025-12-03 11:29:09.892 | DEBUG    | cwl_loader:load_cwl_from_yaml:145 - Parsing the raw CWL document to the CWL Utils DOM...
# 2025-12-03 11:29:10.451 | DEBUG    | cwl_loader:load_cwl_from_yaml:158 - Raw CWL document successfully parsed to the CWL Utils DOM!
# 2025-12-03 11:29:10.452 | DEBUG    | cwl_loader:load_cwl_from_yaml:160 - Dereferencing the steps[].run...
# 2025-12-03 11:29:10.452 | DEBUG    | cwl_loader:_on_process:78 - Checking if ../cwl-workflow/pattern-11.cwl#clt must be externally imported...
# 2025-12-03 11:29:10.452 | DEBUG    | cwl_loader:_on_process:82 - run_url: ../cwl-workflow/pattern-11.cwl - uri: ../cwl-workflow/pattern-11.cwl
# 2025-12-03 11:29:10.453 | DEBUG    | cwl_loader:load_cwl_from_yaml:167 - steps[].run successfully dereferenced! Dereferencing the FQNs...
# 2025-12-03 11:29:10.453 | DEBUG    | cwl_loader:load_cwl_from_yaml:171 - CWL document successfully dereferenced! Now verifying steps[].run integrity...
# 2025-12-03 11:29:10.453 | DEBUG    | cwl_loader:load_cwl_from_yaml:175 - All steps[].run link are resolvable!
# 2025-12-03 11:29:10.453 | DEBUG    | cwl_loader:load_cwl_from_yaml:178 - Sorting Process instances by dependencies....
# 2025-12-03 11:29:10.453 | DEBUG    | cwl_loader:load_cwl_from_yaml:180 - Sorting process is over.
# 2025-12-03 11:29:10.453 | DEBUG    | cwl_loader:_load_cwl_from_stream:240 - Stream from ../cwl-workflow/pattern-11.cwl successfully load!

# %% [markdown]
# ## Application Package Pattern-11
#
# This pattern uses as input a `File` and a `Directory`

# %%
wf.plot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=279x535>

# %% [markdown]
# ### Inputs

# %%
wf.display_inputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `aoi` | `string` | area of interest | area of interest as a bounding box |
# | `epsg` | `string` | EPSG code | EPSG code |
# | `bands` | `string[]` | bands used for the NDWI | bands used for the NDWI |
# | `item` | `Directory` | Landsat-8/9 acquisition reference | Landsat-8/9 acquisition reference |
# | `dem` | `File` | Digital Elevation Model (DEM) | Digital Elevation Model (DEM) geotiff |

# %% [markdown]
# ### Steps

# %%
wf.display_steps()
# Out:
# | Id | Runs | Label | Doc |
# | --- | --- | --- | --- |
# | `step` | `#clt` | None | None |

# %% [markdown]
# ### Outputs

# %%
wf.display_outputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `water_bodies` | `Directory` | Water bodies detected | Water bodies detected based on the NDWI and otsu threshold |

# %% [markdown]
# ## Data flow management

# %%
w = WorkflowWrapper(workflow=wf.workflow, entrypoint=entrypoint)
wrapped = w.wrap()

app_cwl_file = f".{entrypoint}.cwl"

with open(app_cwl_file, "w") as f:
    dump_cwl(process=wrapped, stream=f)
# Out:
# 2025-12-03 11:29:11.287 | DEBUG    | cwl_loader:load_cwl_from_location:228 - Loading CWL document from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in.cwl...
# 2025-12-03 11:29:11.532 | DEBUG    | cwl_loader:_load_cwl_from_stream:231 - Reading stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in.cwl...
# 2025-12-03 11:29:11.536 | DEBUG    | cwl_loader:load_cwl_from_stream:203 - CWL data of type <class 'ruamel.yaml.comments.CommentedMap'> successfully loaded from stream
# 2025-12-03 11:29:11.536 | DEBUG    | cwl_loader:load_cwl_from_yaml:130 - Updating the model from version 'v1.0' to version 'v1.2'...
# 2025-12-03 11:29:11.536 | DEBUG    | cwl_loader:load_cwl_from_yaml:141 - Raw CWL document successfully updated to v1.2!
# 2025-12-03 11:29:11.537 | DEBUG    | cwl_loader:load_cwl_from_yaml:145 - Parsing the raw CWL document to the CWL Utils DOM...
# 2025-12-03 11:29:12.133 | DEBUG    | cwl_loader:load_cwl_from_yaml:158 - Raw CWL document successfully parsed to the CWL Utils DOM!
# 2025-12-03 11:29:12.133 | DEBUG    | cwl_loader:load_cwl_from_yaml:160 - Dereferencing the steps[].run...
# 2025-12-03 11:29:12.134 | DEBUG    | cwl_loader:load_cwl_from_yaml:167 - steps[].run successfully dereferenced! Dereferencing the FQNs...
# 2025-12-03 11:29:12.134 | DEBUG    | cwl_loader:load_cwl_from_yaml:171 - CWL document successfully dereferenced! Now verifying steps[].run integrity...
# 2025-12-03 11:29:12.134 | DEBUG    | cwl_loader:load_cwl_from_yaml:175 - All steps[].run link are resolvable!
# 2025-12-03 11:29:12.134 | DEBUG    | cwl_loader:load_cwl_from_yaml:178 - Sorting Process instances by dependencies....
# 2025-12-03 11:29:12.134 | DEBUG    | cwl_loader:load_cwl_from_yaml:180 - Sorting process is over.
# 2025-12-03 11:29:12.135 | DEBUG    | cwl_loader:_load_cwl_from_stream:240 - Stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in.cwl successfully load!
# 2025-12-03 11:29:12.135 | DEBUG    | cwl_loader:load_cwl_from_location:228 - Loading CWL document from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in-file.cwl...
# 2025-12-03 11:29:12.351 | DEBUG    | cwl_loader:_load_cwl_from_stream:231 - Reading stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in-file.cwl...
# 2025-12-03 11:29:12.355 | DEBUG    | cwl_loader:load_cwl_from_stream:203 - CWL data of type <class 'ruamel.yaml.comments.CommentedMap'> successfully loaded from stream
# 2025-12-03 11:29:12.356 | DEBUG    | cwl_loader:load_cwl_from_yaml:130 - Updating the model from version 'v1.0' to version 'v1.2'...
# 2025-12-03 11:29:12.356 | DEBUG    | cwl_loader:load_cwl_from_yaml:141 - Raw CWL document successfully updated to v1.2!
# 2025-12-03 11:29:12.356 | DEBUG    | cwl_loader:load_cwl_from_yaml:145 - Parsing the raw CWL document to the CWL Utils DOM...
# 2025-12-03 11:29:12.786 | DEBUG    | cwl_loader:load_cwl_from_yaml:158 - Raw CWL document successfully parsed to the CWL Utils DOM!
# 2025-12-03 11:29:12.787 | DEBUG    | cwl_loader:load_cwl_from_yaml:160 - Dereferencing the steps[].run...
# 2025-12-03 11:29:12.787 | DEBUG    | cwl_loader:load_cwl_from_yaml:167 - steps[].run successfully dereferenced! Dereferencing the FQNs...
# 2025-12-03 11:29:12.787 | DEBUG    | cwl_loader:load_cwl_from_yaml:171 - CWL document successfully dereferenced! Now verifying steps[].run integrity...
# 2025-12-03 11:29:12.787 | DEBUG    | cwl_loader:load_cwl_from_yaml:175 - All steps[].run link are resolvable!
# 2025-12-03 11:29:12.787 | DEBUG    | cwl_loader:load_cwl_from_yaml:178 - Sorting Process instances by dependencies....
# 2025-12-03 11:29:12.788 | DEBUG    | cwl_loader:load_cwl_from_yaml:180 - Sorting process is over.
# 2025-12-03 11:29:12.788 | DEBUG    | cwl_loader:_load_cwl_from_stream:240 - Stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in-file.cwl successfully load!
# 2025-12-03 11:29:12.788 | DEBUG    | cwl_loader:load_cwl_from_location:228 - Loading CWL document from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-out.cwl...
# 2025-12-03 11:29:13.067 | DEBUG    | cwl_loader:_load_cwl_from_stream:231 - Reading stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-out.cwl...
# 2025-12-03 11:29:13.072 | DEBUG    | cwl_loader:load_cwl_from_stream:203 - CWL data of type <class 'ruamel.yaml.comments.CommentedMap'> successfully loaded from stream
# 2025-12-03 11:29:13.072 | DEBUG    | cwl_loader:load_cwl_from_yaml:130 - Updating the model from version 'v1.0' to version 'v1.2'...
# 2025-12-03 11:29:13.072 | DEBUG    | cwl_loader:load_cwl_from_yaml:141 - Raw CWL document successfully updated to v1.2!
# 2025-12-03 11:29:13.072 | DEBUG    | cwl_loader:load_cwl_from_yaml:145 - Parsing the raw CWL document to the CWL Utils DOM...
# 2025-12-03 11:29:13.524 | DEBUG    | cwl_loader:load_cwl_from_yaml:158 - Raw CWL document successfully parsed to the CWL Utils DOM!
# 2025-12-03 11:29:13.525 | DEBUG    | cwl_loader:load_cwl_from_yaml:160 - Dereferencing the steps[].run...
# 2025-12-03 11:29:13.525 | DEBUG    | cwl_loader:load_cwl_from_yaml:167 - steps[].run successfully dereferenced! Dereferencing the FQNs...
# 2025-12-03 11:29:13.525 | DEBUG    | cwl_loader:load_cwl_from_yaml:171 - CWL document successfully dereferenced! Now verifying steps[].run integrity...
# 2025-12-03 11:29:13.526 | DEBUG    | cwl_loader:load_cwl_from_yaml:175 - All steps[].run link are resolvable!
# 2025-12-03 11:29:13.526 | DEBUG    | cwl_loader:load_cwl_from_yaml:178 - Sorting Process instances by dependencies....
# 2025-12-03 11:29:13.526 | DEBUG    | cwl_loader:load_cwl_from_yaml:180 - Sorting process is over.
# 2025-12-03 11:29:13.526 | DEBUG    | cwl_loader:_load_cwl_from_stream:240 - Stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-out.cwl successfully load!
# 2025-12-03 11:29:13.527 | INFO     | eoap_cwlwrap.types:_validate_stage_in:281 - Validating stage-in 'my-asthonishing-stage-in-directory'...
# 2025-12-03 11:29:13.527 | INFO     | eoap_cwlwrap.types:_validate_stage_in:303 - stage-in 'my-asthonishing-stage-in-directory' is valid
# 2025-12-03 11:29:13.527 | INFO     | eoap_cwlwrap.types:_validate_stage_in:281 - Validating stage-in 'my-asthonishing-stage-in-file'...
# 2025-12-03 11:29:13.527 | INFO     | eoap_cwlwrap.types:_validate_stage_in:303 - stage-in 'my-asthonishing-stage-in-file' is valid
# 2025-12-03 11:29:13.527 | INFO     | eoap_cwlwrap.types:validate_stage_out:339 - Validating stage-out 'my-super-stage-out'...
# 2025-12-03 11:29:13.528 | INFO     | eoap_cwlwrap.types:validate_stage_out:361 - stage-out 'my-super-stage-out' is valid
# 2025-12-03 11:29:13.528 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:101 - Building the CWL Orchestrator Workflow...
# 2025-12-03 11:29:13.528 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:130 - Analyzing pattern-11 inputs...
# 2025-12-03 11:29:13.529 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:146 - * pattern-11/aoi: string
# 2025-12-03 11:29:13.529 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:146 - * pattern-11/epsg: string
# 2025-12-03 11:29:13.529 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:146 - * pattern-11/bands: string[]
# 2025-12-03 11:29:13.530 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:146 - * pattern-11/item: Directory
# 2025-12-03 11:29:13.530 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:159 -   Directory type detected, creating a related 'directory_stage_in_0'...
# 2025-12-03 11:29:13.530 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:161 -   Converting Directory to URL-compatible type...
# 2025-12-03 11:29:13.531 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:165 -   Directory converted to https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI
# 2025-12-03 11:29:13.531 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:206 -   Connecting 'app/item' to 'directory_stage_in_0' output...
# 2025-12-03 11:29:13.531 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:146 - * pattern-11/dem: File
# 2025-12-03 11:29:13.532 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:159 -   File type detected, creating a related 'file_stage_in_0'...
# 2025-12-03 11:29:13.532 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:161 -   Converting File to URL-compatible type...
# 2025-12-03 11:29:13.532 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:165 -   File converted to https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI
# 2025-12-03 11:29:13.534 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:206 -   Connecting 'app/dem' to 'file_stage_in_0' output...
# 2025-12-03 11:29:13.534 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:257 - Analyzing pattern-11 outputs...
# 2025-12-03 11:29:13.534 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:263 - * pattern-11/water_bodies: Directory
# 2025-12-03 11:29:13.535 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:268 -   Directory type detected, creating a related 'stage_out_0'...
# 2025-12-03 11:29:13.535 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:270 -   Converting Directory to URL-compatible type...
# 2025-12-03 11:29:13.535 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:274 -   Directory converted to https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI
# 2025-12-03 11:29:13.536 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:315 -   Connecting 'app/water_bodies' to 'stage_out_0' output...
# 2025-12-03 11:29:13.536 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:390 - Orchestrator Workflow built in 0.0080 seconds

# %%
wf = WorkflowViewer(cwl_file=app_cwl_file, workflow=wrapped, entrypoint="main")

wf.plot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=1079x1601>

# %% [markdown]
# ### Workflow sequence diagram

# %%
wf.display_sequence_diagram()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=2278x1559>

# %% [markdown]
# ### Inputs

# %%
wf.display_inputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `aoi` | `string` | area of interest - pattern-11/aoi | area of interest as a bounding box - This parameter is derived from pattern-11/aoi |
# | `epsg` | `string` | EPSG code - pattern-11/epsg | EPSG code - This parameter is derived from pattern-11/epsg |
# | `bands` | `string[]` | bands used for the NDWI - pattern-11/bands | bands used for the NDWI - This parameter is derived from pattern-11/bands |
# | `another_input` | `string` | Another Input - my-asthonishing-stage-in-directory/another_input | An additional input for demonstration purposes - This parameter is derived from my-asthonishing-stage-in-directory/another_input |
# | `item` | `https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI` | Landsat-8/9 acquisition reference - pattern-11/item | Landsat-8/9 acquisition reference - This parameter is derived from pattern-11/item |
# | `another_input` | `string` | Another Input - my-asthonishing-stage-in-file/another_input | An additional input for demonstration purposes - This parameter is derived from my-asthonishing-stage-in-file/another_input |
# | `dem` | `https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI` | Digital Elevation Model (DEM) - pattern-11/dem | Digital Elevation Model (DEM) geotiff - This parameter is derived from pattern-11/dem |
# | `s3_bucket` | `string` | my-super-stage-out/s3_bucket | This parameter is derived from: my-super-stage-out/s3_bucket |
# | `sub_path` | `string` | my-super-stage-out/sub_path | This parameter is derived from: my-super-stage-out/sub_path |
# | `aws_access_key_id` | `string` | my-super-stage-out/aws_access_key_id | This parameter is derived from: my-super-stage-out/aws_access_key_id |
# | `aws_secret_access_key` | `string` | my-super-stage-out/aws_secret_access_key | This parameter is derived from: my-super-stage-out/aws_secret_access_key |
# | `region_name` | `string` | my-super-stage-out/region_name | This parameter is derived from: my-super-stage-out/region_name |
# | `endpoint_url` | `string` | my-super-stage-out/endpoint_url | This parameter is derived from: my-super-stage-out/endpoint_url |

# %% [markdown]
# ### Steps

# %%
wf.display_steps()
# Out:
# | Id | Runs | Label | Doc |
# | --- | --- | --- | --- |
# | `directory_stage_in_0` | `#my-asthonishing-stage-in-directory` | None | None |
# | `file_stage_in_0` | `#my-asthonishing-stage-in-file` | None | None |
# | `app` | `#pattern-11` | None | None |
# | `stage_out_0` | `#my-super-stage-out` | None | None |

# %% [markdown]
# ### Outputs

# %%
wf.display_outputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `water_bodies` | `https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI` | Water bodies detected | Water bodies detected based on the NDWI and otsu threshold |

# %% [markdown]
# ## Execution

# %%
from cwltool.main import main
from io import StringIO
import argparse
import yaml

# %%
params = {
    "aoi": "-118.985,38.432,-118.183,38.938",
    "epsg": "EPSG:4326",
    "bands": ["green", "nir08"],
    "item": {
        "class": "https://raw.githubusercontent.com/eoap/schemas/main/url.yaml#URL",
        "value": "https://planetarycomputer.microsoft.com/api/stac/v1/collections/landsat-c2-l2/items/LC08_L2SP_042033_20231007_02_T1",
    },
    "dem": {
        "class": "https://raw.githubusercontent.com/eoap/schemas/main/url.yaml#URL",
        "value": "https://elevationeuwest.blob.core.windows.net/copernicus-dem/COP30_hh/Copernicus_DSM_COG_10_N38_00_W119_00_DEM.tif",
    },
}
additional_params = {
    "another_input": "some_value",
    "s3_bucket": "my-bucket",
    "sub_path": "my/sub/path",
    "aws_access_key_id": "test",
    "aws_secret_access_key": "test",
    "region_name": "us-west-1",
    "endpoint_url": "https://s3.us-west-1.amazonaws.com",
}

with open(".params.yaml", "w") as f:
    yaml.dump({**params, **additional_params}, f)

md = f"""

### Inputs

```json
{json.dumps(params, indent=2)}
```
"""

display(Markdown(md))
# Out:
# ### Inputs
#
# ```json
# {
#   "aoi": "-118.985,38.432,-118.183,38.938",
#   "epsg": "EPSG:4326",
#   "bands": [
#     "green",
#     "nir08"
#   ],
#   "item": {
#     "class": "https://raw.githubusercontent.com/eoap/schemas/main/url.yaml#URL",
#     "value": "https://planetarycomputer.microsoft.com/api/stac/v1/collections/landsat-c2-l2/items/LC08_L2SP_042033_20231007_02_T1"
#   },
#   "dem": {
#     "class": "https://raw.githubusercontent.com/eoap/schemas/main/url.yaml#URL",
#     "value": "https://elevationeuwest.blob.core.windows.net/copernicus-dem/COP30_hh/Copernicus_DSM_COG_10_N38_00_W119_00_DEM.tif"
#   }
# }
# ```

# %%
parsed_args = argparse.Namespace(
    podman=False,
    debug=False,
    validate=False,
    outdir="./runs",
    workflow=f"{app_cwl_file}#main",
    job_order=[".params.yaml"],
)

stream_out = StringIO()
stream_err = StringIO()

res = main(
    args=parsed_args,
    stdout=stream_out,
    stderr=stream_err,
)

if res == 0:
    md = f"""

### Outputs

```json
{stream_out.getvalue()}
```
    """
else:
    md = f"""

### Errors

CWL execution terminated with errors:

```
{stream_err.getvalue()}
```
    """

display(Markdown(md))
# Out:
# ### Outputs
#
# ```json
# {
#     "water_bodies": {
#         "value": "s3://my-bucket/my/sub/path-j6j46y/catalog.json",
#         "type": "https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI"
#     }
# }
# ```
